# %%
import pandas as pd
import os
from bs4 import BeautifulSoup
import re
import glob
import random
from tqdm import tqdm
import json

# disable chained assignment warning
pd.options.mode.chained_assignment = None

tqdm.pandas()

# %%
# go to data/htmls/ for each folder make a list of 100 random htmls and store them as a zip file in the root folder
import os
import random
import zipfile

# Path: hrefs_analysis.ipynb
DATA_DIR = 'data/'
HTML_DIR = 'data/htmls/'

# get the list of folders
folders = os.listdir(HTML_DIR)
folders
# Out:
# ['clarintags',
#  'rionegro',
#  'clarin',
#  'c5n',
#  'lanacion',
#  'infobae',
#  'pagina12',
#  'lavoz',
#  'eldestapeweb',
#  'perfil']

# %% [markdown]
# ### Make a zipfile of 100 random htmls for each new-web to obeserve for writing a scrapper.

# %%
# # for each folder make a list of 100 random htmls and store them as a zip file in the root folder
# for folder in folders:
#     # get the list of htmls
#     htmls = os.listdir(HTML_DIR+folder)
#     # get 100 random htmls
#     random_htmls = random.sample(htmls, 100)
#     # make a zip file
#     zip_file = zipfile.ZipFile(DATA_DIR+folder+'.zip', 'w')
#     for html in random_htmls:
#         zip_file.write(HTML_DIR+folder+'/'+html, html)
#     zip_file.close()

# %% [markdown]
# ### Define a scrape function for each website

# %%
# # choose 100 random htmls from c5n
# # get the list of htmls

# # glob 100 random htmls from data/htmls/*/
# html_folders = os.listdir('data/htmls/')
# html_dict = {}
# for folder in html_folders:
#     html_dict[folder] = random.sample(glob.glob(f'data/htmls/{folder}/*.html'), 10)


# scraping_dict = {
#                   # tag, attributes, classifier
#     'c5n' : {
#         'title': ['h1', {'class': 'news-headline__title'}],
#         'date': ['time', {'itemprop': 'datePublished'}, 'text'],
#         'text': [True, {'class': re.compile('article-body article-body')}]
#     },

#     'clarin':
#     {
#         'title': ['h1', {'class': 'storyTitle'}],
#         'date': ['meta', {'itemprop': 'datePublished'}, 'content'],
#         'text': ['div', {'class': 'StoryTextContainer'}]
#     },

#     'eldestapeweb':{
#         'title': ['h1', {'class': 'titulo'}],
#         'date': ['div', {'class': 'fecha'}, 'text'],
#         'text': ['div', {'itemprop': 'articleBody'}]
#     },

#     'lanacion':{
#         'title': ['h1', {'class': re.compile('com-title')}],
#         'date': ['span', {'class': 'mod-date'}, 'text'],
#         'text': [True, {'class': re.compile('com-paragraph')}]
#     },
    
#     'lavoz':{
#         'title': ['h1', {'class': re.compile('false h1 boldbold')}],
#         'date': ['div', {'class': re.compile('story-meta-datetime')}, 'text'],
#         'text': ['div', {'class': re.compile('story-content')}]

#     },

#     'perfil':{
#         'title': ['h1', {'class': 'article__title'}],
#         'date': ['time', {'class': 'article__date'}, 'text'],
#         'text': ['div', {'class': re.compile('article__content')}]
#     },
    
#     'pagina12':{
#         'title': ['h1', {}],
#         'date': ['time', {}, 'text'],
#         'text': ['div', {'class': re.compile('article-main-content article-text')}]

#     },
    
#     'infobae' :{
#         'title': ['h1', {'class': re.compile('article-headline')} ],
#         'date': ['span', {'class': 'sharebar-article-date'}, 'text'],
#         'text': ['div', {'class': re.compile('body-article')}]
#     },

#     'rionegro':{
#         'title': ['h1', {'class': 'newsfull__title'}],
#         'date': ['time', {'class': 'newsfull__time'}, 'text'],
#         'text': ['div', {'class': 'newsfull__body'}]
#     },

# }

# # # c5n scrapper
# for html in html_dict['infobae']:

#     try:
#         print(html)
#         # read the html
#         with open(html, 'r') as f:
#             html_file = f.read()
#         # parse the html
#         soup = BeautifulSoup(html_file, 'html.parser')
#         website = html.split('/')[2]
#         print(website)
#         title_tag = scraping_dict[website]['title']
#         date_tag = scraping_dict[website]['date']
#         text_tag = scraping_dict[website]['text']
#         # get the title in h1 with class 'news-headline__title'
#         title = soup.find(name=title_tag[0], attrs=title_tag[1]).text
#         print(title)
#         # get the date in time with itemprop 'datePublished' stored in 'content' tag
#         date = soup.find(date_tag[0], date_tag[1])[date_tag[2]] if date_tag[2]!='text' else soup.find(date_tag[0], date_tag[1]).text
#         print(date)
#         # get the text of any class containing keywords: 'article-body article-body'
#         text_elements = soup.find_all(name=text_tag[0], attrs=text_tag[1])
#         print(len(text_elements))


#         text = ''
#         for text_element in text_elements:
#             # get all the <p> tags inside of text_element and their text if the current text_element is not a <p> tag
#             if text_element.name != 'p':
#                 p_tags = text_element.find_all('p')
#                 for p_tag in p_tags:
#                     text += '\n'+p_tag.text.strip()
#             else:
#                 text += '\n'+text_element.text.strip()
#         print('Date:', date)
#         print('Title:', title)
#         print('Text:', text)
#         print("-----------------------------------------")
#         print()
        
#     except Exception as e:
#         # print('Date:', date)
#         # print('Title:', title)
#         # print('Text:', text)
#         print('Error:', e) 
#         print("-----------------------------------------")

# %%
def rename_yt_csvs():
    # rename the csvs in the candidates_csvs folder.
    # the csvs are named as: 'candidato nombre apellido_dates.csv'
    # rename it to: 'candidato_nombre_apellido.csv'
    # get the list of csvs
    csvs = glob.glob('candidates_csvs/*.csv')

    for csv in csvs:
        # get the name of the csv
        csv_name = csv.split('/')[1]
        # get the name of the candidate
        candidate_name = csv_name.split('_2023')[0].lower().replace(' ', '_')
        # rename the csv
        os.rename(csv, 'candidates_csvs/'+candidate_name+'.csv')

# %% [markdown]
# ### Making a dataframe from yt_transcripts and the scraped data

# %%
# reading the scraped data
df_scraped = pd.read_csv('data/htmls_scraped/scraped_data.csv')

twitter_df = pd.read_csv('data/twitter_dump_.csv')

csvs = glob.glob('candidates_csvs/*.csv')
df_candidates = pd.DataFrame()
for csv in csvs:
    # read the csv only 1,2 and 4th columns
    df_candidates = pd.concat([df_candidates, pd.read_csv(csv, usecols=[2,3,4], names=['vid_id', 'date', 'title'])])
    df_candidates = df_candidates.reset_index(drop=True)


transcripts_dict = {}
for json_file in glob.glob('data/transcripts/*.json'):
    candidate_name = json_file.split('/')[2].split('.json')[0]
    # read the json file
    with open(json_file, 'r') as f:
        json_data = json.load(f)
    for vid_id, transcript in json_data.items():
        transcripts_dict[vid_id] = transcript
df_transcripts = pd.DataFrame(list(transcripts_dict.items()), columns=['vid_id', 'text'])


# merge the transcripts with the df_candidates based on the vid_id
merged_df = pd.merge(df_candidates, df_transcripts, on='vid_id', how='left')  # or how='left', etc. as per requirement
merged_df = merged_df.dropna()

# drop vid_id column and a source column for which all the entries should be youtube
merged_df = merged_df.drop(['vid_id'], axis=1)
merged_df['source'] = 'youtube'
merged_df = merged_df.reset_index(drop=True)
merged_df
# Out:
#                        date  \
# 0      2023-09-29T03:37:37Z
# 1      2023-09-29T02:14:21Z
# 2      2023-09-29T00:08:26Z
# 3      2023-09-28T23:08:20Z
# 4      2023-09-28T22:18:29Z
# ...                     ...
# 56873  2023-08-02T10:09:42Z
# 56874  2023-08-02T02:45:23Z
# 56875  2023-08-01T21:00:12Z
# 56876  2023-07-31T21:00:09Z
# 56877  2023-07-31T14:00:01Z
#
#                                                    title  \
# 0            Lançamento da BMW R1300GS ao vivo de Berlim
# 1                               BANDNEWS MANAUS 28.09.23
# 2                          ALERTA | AO VIVO | 28/09/2023
# 3                Marcelo Ramal por Radio Locos por Bs As
# 4        Jorge Altamira por Radio Horizonte de Bariloche
# ...                                                  ...
# 56873  Trinchera (01/08/23): Entrevista a Cesar Biond...
# 56874              NICOLAS MORAS-LOS LIBERALES (PARODIA)
# 56875  AGUSTINA KAMPFER entrevistó a CÉSAR BIONDINI, ...
# 56876  Entrevista a CÉSAR BIONDINI en &quot;Somos PM&...
# 56877  Elecciones 2023 | Cobertura especial de Canal ...
#
#                                                     text   source
# 0                                    transcript_disabled  youtube
# 1                                    transcript_disabled  youtube
# 2                                    transcript_disabled  youtube
# 3      Marcelo ramal es un ex legislador de la\nciuda...  youtube
# 4      que Altamira estamos hablando de un\nreferente...  youtube
# ...                                                  ...      ...
# 56873                                transcript_disabled  youtube
# 56874  buenas noches amigos soy Nicolás moraz\nesta n...  youtube
# 56875  le voy a dar la bienvenida al próximo\ninvitad...  youtube
# 56876  [Música]\nbueno y de Cara a las paso de dentro...  youtube
# 56877  en agosto y de noticias y ganar nueve\nvan a s...  youtube
#
# [56878 rows x 4 columns]

# %%
twitter_df
# Out:
#               candidate   source        date  \
# 0       Juan Schiaretti  twitter  2023-10-20
# 1       Juan Schiaretti  twitter  2023-10-20
# 2       Juan Schiaretti  twitter  2023-10-19
# 3       Juan Schiaretti  twitter  2023-10-19
# 4       Juan Schiaretti  twitter  2023-10-20
# ...                 ...      ...         ...
# 4719  Patricia Bullrich  twitter  2023-08-04
# 4720  Patricia Bullrich  twitter  2023-08-02
# 4721  Patricia Bullrich  twitter  2023-08-02
# 4722  Patricia Bullrich  twitter  2023-07-31
# 4723  Patricia Bullrich  twitter  2023-07-31
#
#                                                    text
# 0     peronista hay uno solo y se llama juan schiaretti
# 1     les gustaria tenerme como amigo y que los invi...
# 2     en vivo | cierre de campaña de juan schiaretti...
# 3     juan schiaretti: “si la argentina fuese como c...
# 4     le tenemos que dar una oportunidad a la argent...
# ...                                                 ...
# 4719                      muy bueno el spot de bullrich
# 4720                     11 días patricia bullrich 2023
# 4721  mauricio macri diciendo que vidal se había com...
# 4722                 con bullrich se repite la historia
# 4723           milei en los ' 70 / bullrich en los ' 70
#
# [4724 rows x 4 columns]

# %%
# rename 'website' coulumn to 'source'
df_scraped = df_scraped.rename(columns={'website': 'source'})

# append the df_scraped with the merged_df based on the title
df = pd.concat([df_scraped, merged_df], ignore_index=True)

# drop duplicate rows based on the title
df = df.drop_duplicates(subset=['title'])

# drop the rows with 'transcript_disabled' in text
df = df[df['text']!='transcript_disabled']

df = df.reset_index(drop=True)



df
# Out:
#          source                                              title  \
# 0        clarin  Un encuestador K midió a Cristina Kirchner con...
# 1        clarin   A los amigos todo, a los enemigos Estado ausente
# 2        clarin  Una funcionaria de Juan Grabois manejará un pl...
# 3        clarin  Kicillof ya revisa los acuerdos de precios que...
# 4        clarin  Un intendente del PJ cruzó a Juan Grabois y ne...
# ...         ...                                                ...
# 346468  youtube  Reportaje a CÉSAR BIONDINI en el programa &quo...
# 346469  youtube              NICOLAS MORAS-LOS LIBERALES (PARODIA)
# 346470  youtube  AGUSTINA KAMPFER entrevistó a CÉSAR BIONDINI, ...
# 346471  youtube  Entrevista a CÉSAR BIONDINI en &quot;Somos PM&...
# 346472  youtube  Elecciones 2023 | Cobertura especial de Canal ...
#
#                         date  \
# 0       2022-10-20T09:37:00Z
# 1       2020-10-26T22:28:43Z
# 2       2022-04-17T16:07:48Z
# 3       2013-11-25T00:08:51Z
# 4       2021-08-07T16:43:20Z
# ...                      ...
# 346468  2023-08-02T21:00:11Z
# 346469  2023-08-02T02:45:23Z
# 346470  2023-08-01T21:00:12Z
# 346471  2023-07-31T21:00:09Z
# 346472  2023-07-31T14:00:01Z
#
#                                                      text
# 0       \nSi se repasan los casi 20 años de kirchneris...
# 1       \nSólo hay que mirar un poco más allá del cent...
# 2       \n“Van a haber 1, 5, 20 Guernicas siempre y cu...
# 3       \nEl flamante equipo económico optó por trabaj...
# 4       \nEl intendente peronista de Ituzaingó Alberto...
# ...                                                   ...
# 346468  va César Buen día Qué tal\nQué tal Buen día pa...
# 346469  buenas noches amigos soy Nicolás moraz\nesta n...
# 346470  le voy a dar la bienvenida al próximo\ninvitad...
# 346471  [Música]\nbueno y de Cara a las paso de dentro...
# 346472  en agosto y de noticias y ganar nueve\nvan a s...
#
# [346473 rows x 4 columns]

# %%
# # show 10 entries for each website
# for website in df['source'].unique():
#     print(website)
#     display(df[df['source']==website].head(10))
#     print('---------------------------------------------')

# %%
# preprocess the text column
def preprocess_text(text):
    text = re.sub('\n+',' ',text)
    text = re.sub(' +',' ',text)
    text = re.sub('\t+',' ',text)
    text = re.sub('\r+',' ',text)
    text = text.lower()
    text = text.strip()
    return text


# Mapping of Spanish month names to English, include 3 letter words for month as well
month_mapping = {
    'enero': 'January',
    'febrero': 'February',
    'marzo': 'March',
    'abril': 'April',
    'mayo': 'May',
    'junio': 'June',
    'julio': 'July',
    'agosto': 'August',
    'septiembre': 'September',
    'octubre': 'October',
    'noviembre': 'November',
    'diciembre': 'December',
    'ene': 'January',
    'feb': 'February',
    'mar': 'March',
    'abr': 'April',
    'may': 'May',
    'jun': 'June',
    'jul': 'July',
    'ago': 'August',
    'sep': 'September',
    'oct': 'October',
    'nov': 'November',
    'dic': 'December'
}

# Mapping of Spanish day names to English in lower case letters
day_mapping = {
    'lunes': 'Monday',
    'martes': 'Tuesday',
    'miércoles': 'Wednesday',
    'jueves': 'Thursday',
    'viernes': 'Friday',
    'sábado': 'Saturday',
    'domingo': 'Sunday'
}

# month to number mapping using three letter words
month_to_number = {
    'jan': '01',
    'feb': '02',
    'mar': '03',
    'apr': '04',
    'may': '05',
    'jun': '06',
    'jul': '07',
    'aug': '08',
    'sep': '09',
    'oct': '10',
    'nov': '11',
    'dec': '12'
}

def clean_dates(date):
    # remove newlines
    date = re.sub('\n', '', date)
    date = date.split('|')[0]
    date = date.split('T')[0]
    date = date.replace('Publicado: ', '')
    # remove a.m. and p.m.
    date = re.sub('a.m.|p.m.', '', date)
    # remove 'ES(T)'
    date = date.replace('ES', '')
    # remove the 24h time
    date = re.sub('\d{2}:\d{2}', '', date)
    # remove '-'
    date = date.replace(' - ', '')

    date = date.lower()
    # remove 'de' and commas
    date = date.replace('de', '')
    date = date.replace(',', '')
    # remove spanish days
    for day in day_mapping.keys():
        date = date.replace(day, '')
    # replace spanish months with English
    for month in month_mapping.keys():
        date = date.replace(month, month_mapping[month])
    
    date = date.lower()
    # remove extra spaces
    date = re.sub(' +', ' ', date)

    # convert 'year-month-day' pattern to this to day-month-year
    if re.search('\d{4}-\d{2}-\d{2}', date):
        date = date.split('-')
        date = date[2]+'-'+date[1]+'-'+date[0]

    date = date.strip()
    # convert day/month/year to day-month-year
    if re.search('\d{1,2}/\d{1,2}/\d{4}', date):
        date = date.split('/')
        date = date[0]+'-'+date[1]+'-'+date[2]
    
    date = date.lower()
    # # convert day Month(english) year to day-month-year
    if re.search('\d+ ([A-Za-z]+) \d+', date):
        split = date.split(' ')
        date = split[0]+'-'+month_to_number[split[1][:3]]+'-'+split[2]
    
    return date

# %%
df['date'] = df['date'].astype(str).apply(clean_dates)
# drop all the rows with null values
df = df.dropna()
twitter_df = twitter_df.dropna()
# drop all the non-numerical values for new_dates
df = df[df['date'].progress_apply(lambda x: re.search('\d+-\d+-\d+', x)!=None)]
# convert to datetime
df['date'] = pd.to_datetime(df['date'], format='%d-%m-%Y')
twitter_df['date'] = pd.to_datetime(df['date'], format='%d-%m-%Y')
# Out:
# 100%|██████████| 345352/345352 [00:00<00:00, 518596.02it/s]

# %%
# combine title and text columns
# df['text'] = df['title'] + '. ' + df['text']
# drop the title column
# df = df.drop(['title'], axis=1)
# df['text'] = df['text'].progress_apply(preprocess_text)
twitter_df['text'] = twitter_df['text'].progress_apply(preprocess_text)
# Out:
#   0%|          | 0/4721 [00:00<?, ?it/s]
# 100%|██████████| 4721/4721 [00:00<00:00, 43779.34it/s]

# %%
# show 10 entries for each website
for website in df['source'].unique():
    print(website)
    display(df[df['source']==website].head(5))
    print('---------------------------------------------')
# Out:
# clarin
#    source                                              title       date  \
# 0  clarin  Un encuestador K midió a Cristina Kirchner con... 2022-10-20
# 1  clarin   A los amigos todo, a los enemigos Estado ausente 2020-10-26
# 2  clarin  Una funcionaria de Juan Grabois manejará un pl... 2022-04-17
# 3  clarin  Kicillof ya revisa los acuerdos de precios que... 2013-11-25
# 4  clarin  Un intendente del PJ cruzó a Juan Grabois y ne... 2021-08-07
#
#                                                 text
# 0  \nSi se repasan los casi 20 años de kirchneris...
# 1  \nSólo hay que mirar un poco más allá del cent...
# 2  \n“Van a haber 1, 5, 20 Guernicas siempre y cu...
# 3  \nEl flamante equipo económico optó por trabaj...
# 4  \nEl intendente peronista de Ituzaingó Alberto...
# ---------------------------------------------
# rionegro
#         source                                              title       date  \
# 2138  rionegro  Ya está casi todo listo para licitar la obra d... 2022-12-15
# 2139  rionegro  Elecciones en Río Negro: Horne asegura que hub... 2023-04-18
# 2140  rionegro  Desconcierto por el hallazgo del «bebé» del mo... 2023-01-04
# 2141  rionegro  «Me di por vencida»: por qué Marie Kondo ya no... 2023-01-29
# 2142  rionegro  Juan Manzur podría irse de la Jefatura de  Gab... 2022-01-23
#
#                                                    text
# 2138  \nEl Ministerio de Obras Públicas de Nación di...
# 2139  \nLa excandidata a gobernadora Silvia Horne co...
# 2140  \nDescubrieron una «extraña bestia» varada en ...
# 2141  \nMarie Kondo, «la reina del orden», admitió h...
# 2142  \nJuan Luis Manzur presentaría en las próximas...
# ---------------------------------------------
# c5n
#       source                                              title       date  \
# 72256    c5n  Plazos fijos: cuánto gano por depositar 96.000... 2023-08-14
# 72257    c5n  La excelente confitería de Buenos Aires que ha... 2023-09-23
# 72258    c5n  Mick Schumacher se emocionó al recordar a su p... 2022-04-07
# 72259    c5n  La respuesta de Lourdes Sánchez tras los comen... 2023-09-07
# 72260    c5n  Bono para empleadas domésticas: se reintegrará... 2022-12-30
#
#                                                     text
# 72256  \nPara hacerle frente a la inflación, los ahor...
# 72257  \nHace ya algunos años, la tendencia del café ...
# 72258  \nEl piloto alemán Mick Schumacher, hijo del h...
# 72259  \nLa conductora Lourdes Sánchez recibió una cr...
# 72260  \nDespués de haber anunciado el bono para trab...
# ---------------------------------------------
# lanacion
#           source                                              title  \
# 130652  lanacion  China recorta tasas de referencia de préstamos...
# 130653  lanacion  Coronavirus en Argentina: casos en Rauch, Buen...
# 130654  lanacion  Los Simpson, la familia de clase media baja de...
# 130655  lanacion  El Señor de los Anillos: Los Anillos de Poder ...
# 130656  lanacion  Gobierno de Ecuador retoma diálogo con indígen...
#
#              date                                               text
# 130652 2023-06-19  \nShanghái/singapur, 20 jun (reuters) - china ...
# 130653 2021-12-31  \nLa pandemia de coronavirus lleva más de un a...
# 130654 2023-06-17  \nCuando Los Simpson debutaron en 1989, su cre...
# 130655 2022-08-17  \nAmazon Prime Video pisa el acelerador con 'E...
# 130656 2022-06-29  \nEl gobierno de Ecuador anunció este miércole...
# ---------------------------------------------
# infobae
#          source                                              title       date  \
# 186321  infobae  Crónica del Real Madrid - Dallas Mavericks: 12... 2023-10-10
# 186322  infobae  El tremendo accidente de un trapecista chileno... 2023-10-03
# 186323  infobae  Más allá de los abdominales: 12 alimentos esen... 2017-11-10
# 186324  infobae  Las claves fit del entrenador de Meghan Markle... 2020-05-26
# 186325  infobae  Por qué piden que Livia Brito sea expulsada de... 2020-09-08
#
#                                                      text
# 186321  \nEl Real Madrid ganó este martes por 127-123 ...
# 186322  \n(Desde Santiago, Chile) Se trataba de una op...
# 186323  \nAdemás de la pérdida de la peso, otro de los...
# 186324  \nDesde que fue decretado el aislamiento socia...
# 186325  \nLivia Brito, actriz cubana de telenovelas, s...
# ---------------------------------------------
# pagina12
#           source                                              title  \
# 190467  pagina12  Juan Grabois desmintió haber estado internado ...
# 190468  pagina12  "El Norte argentino necesita que Sergio Massa ...
# 190469  pagina12  Myriam Bregman cruzó a Javier Milei: "Es todo ...
# 190470  pagina12   Ahora Massa comienza su búsqueda del voto a voto
# 190471  pagina12  Asoma Juan Grabois: "Esto no es un simulacro. ...
#
#              date                                               text
# 190467 2022-02-06  \nEl dirigente social Juan Grabois desmintió u...
# 190468 2023-09-12  \nEn declaraciones por radio AM 530 el goberna...
# 190469 2023-08-31  \nLa precandidata presidencial por el Frente d...
# 190470 2023-09-27  \nEn el último día para poder hacer anuncios d...
# 190471 2023-05-20  \nDecidido a competir en unas PASO del Frente ...
# ---------------------------------------------
# lavoz
#        source                                              title       date  \
# 191604  lavoz  Juicio al falso médico en Río Cuarto: reñida b... 2023-09-04
# 191605  lavoz  Impactante video: un avión cayó encima de un a... 2023-09-16
# 191606  lavoz  Lana del Rey causó sorpresa al ser vista traba... 2023-07-28
# 191607  lavoz  Talleres goleó a Atlanta por el torneo de asce... 2023-05-07
# 191608  lavoz  Empleadas domésticas: cuánto deben cobrar por ... 2023-05-20
#
#                                                      text
# 191604  \nEl próximo 20 de septiembre se conocerá el v...
# 191605  \nUn trágico episodio tuvo lugar este sábado e...
# 191606  \nLana del Rey fue captada trabajando en un lo...
# 191607  \nEl equipo femenino de Talleres venció este d...
# 191608  \nEmpleadas domésticas perciben un nuevo aumen...
# ---------------------------------------------
# eldestapeweb
#               source                                              title  \
# 212480  eldestapeweb  Salta fue considerada por la revista Time como...
# 212481  eldestapeweb  Sale a subasta una pintura de Picasso valuada ...
# 212482  eldestapeweb  Rusia descartó la posibilidad de una tregua en...
# 212483  eldestapeweb  Ante 50.000 personas y Macron, Francisco recor...
# 212484  eldestapeweb  Karina La Princesita se quebró y le hizo un de...
#
#              date                                               text
# 212480 2022-07-12  \nLa provincia de Salta fue elegida como unos ...
# 212481 2023-04-21  \nUna pintura del español Pablo Picasso (1881-...
# 212482 2022-12-14  \nRusia negó haber recibido una propuesta para...
# 212483 2023-09-23  \nEl papa Francisco recordó hoy desde Marsella...
# 212484 2023-07-08  \nKarina La Princesita es una de las cantantes...
# ---------------------------------------------
# perfil
#         source                                              title       date  \
# 270600  perfil  El kirchnerismo duro bajó un cambio y puso pañ... 2022-07-08
# 270601  perfil  Cómo saber si un neumático es nuevo, usado o s... 2022-10-07
# 270602  perfil  Tres renuncias en 24 horas: los motivos detrás... 2022-12-30
# 270603  perfil  Reino Unido en shock tras la muerte de 4 niños... 2022-12-15
# 270604  perfil  Tailhade cruzó a Rosatti en el Consejo de la M... 2023-05-10
#
#                                                      text
# 270600  \nDespués de conocerse la reunión que el Presi...
# 270601  \nSi bien ya se arribó a un acuerdo entre los ...
# 270602  \nLa última semana del año llegó con la salida...
# 270603  \nUn niño de seis años murió tras haber caído ...
# 270604  \nLa escalada en la tensión entre el oficialis...
# ---------------------------------------------
# youtube
#          source                                              title       date  \
# 309999  youtube            Marcelo Ramal por Radio Locos por Bs As 2023-09-28
# 310000  youtube    Jorge Altamira por Radio Horizonte de Bariloche 2023-09-28
# 310001  youtube  ME SORPRENDIÓ UN CRUCE DE ENORMES TRENES CARGU... 2023-09-28
# 310002  youtube  Charla sobre Inteligencia Artificial: ¿La IA r... 2023-09-28
# 310003  youtube  Julieta Tarrés: Derribando Mitos | Con Santiag... 2023-09-28
#
#                                                      text
# 309999  Marcelo ramal es un ex legislador de la\nciuda...
# 310000  que Altamira estamos hablando de un\nreferente...
# 310001  continuando nuestro recorrido por la\nruta nac...
# 310002  vamos a dar continuidad a este a esta\nactivid...
# 310003  [Música]\n[Aplausos]\n[Música]\n[Aplausos]\n[M...
# ---------------------------------------------

# %%
from unidecode import unidecode

candidates = {
    'Myriam Bregman' :    ['MYRIAM TERESA BREGMA', 'Myriam Bregman', 'Miriam Bregman', 'Miriam Breman', 'Myriam Breman', 'Myriam', 'Miriam',],
    'Gabriel Solano' :    ['GABRIEL ESTEBAN SOLANO', 'Gabriel Solano', 'Solano',],
    'Alejandro Biondini' :    ['ALEJANDRO CESAR BIONDINI', 'Alejandro Biondini', 'Biondini',],
    'Juan Schiaretti' :    ['JUAN SCHIARETTI', 'Juan Schiaretti', 'Juan Schriareti', 'Schiareti', 'Squiareti',],
    'Horacio Rodriguez Larreta'  :    ['HORACIO ANTONIO RODRIGUEZ LARRETA', 'Horacio Rodriguez Larreta', 'Larreta', 'Lareta', 'Sombrilla', 'Pelado',],
    'Patricia Bullrich' :    ['PATRICIA BULLRICH', 'Patricia Bullrich', 'Bullrich', 'Patricia Bulrich', 'Bulrich', 'Patricia', 'Pato', 'Montonera',],
    'Javier Milei' :    ['JAVIER GERARDO MILEI', 'Javier Milei', 'Miley', 'Mi ley', 'Milaw', 'Leon', 'Peluca',],
    'Nazareno Etchepare' :    ['NAZARENO GABRIEL ETCHEPARE', 'Nazareno Etchepare', 'Etchepare',],
    'Ramiro Vasena' :    ['RAMIRO EDUARDO VASENA', 'Ramiro Vasena', 'Ramiro basena', 'Basena', 'Vasena',],
    'Manuela Castañeira' :    ['MANUELA JIMENA CASTAÑEIRA', 'Manuela Castañeira', 'Castañeira', 'Manuela Castanieira', 'Castanieira',],
    'Raul Albarracin' :    ['RAUL HUMBERTO ALBARRACIN', 'Raul Albarracin', 'Albarracin', 'Albaracin',],
    'Raul Castells' :    ['RAUL ANIBAL CASTELLS', 'Raul Castells', 'Raul Castels', 'Castells', 'Castels',],
    'Santiago Cuneo' :    ['GABRIEL SANTIAGO CÚNEO', 'Santiago Cuneo', 'Cuneo',],
    'Jesus Escobar' :    ['JESUS ARNALDO ESCOBAR', 'Jesus Escobar', 'Escobar',],
    'Marcelo Ramal' :    ['MARCELO ARMANDO RAMAL', 'Marcelo Ramal', 'Ramal',],
    'Guillermo Moreno' :    ['MARIO GUILLERMO MORENO', 'Guillermo Moreno', 'Moreno',],
    'Oscar Giardinelli' :    ['OSCAR ALFREDO RAMON GIARDINELLI', 'Oscar Giardinelli', 'Oscar Giardineli', 'Giardinelli', 'Giardineli',],
    'Martin Ayerbe Ortiz'  :    ['MARTIN MIGUEL AYERBE ORTIZ', 'Martin Ayerbe Ortiz', ],
    'Reina Ibañez' :    ['REINA XIOMARA IBAÑEZ', 'Reina Ibañez', 'Reina Xiomara Ibañez', ],
    'Andres Passamonti' :    ['ANDRES GABRIEL PASSAMONTI', 'Andres Passamonti', 'Passamonti', 'Pasamonti', ],
    'Sergio Tomas Massa'  :    ['SERGIO TOMAS MASSA', 'Sergio Tomas Massa', 'Sergio Massa', 'Sergio Masa', 'Masa', 'Massa', 'Panqueque'],
    'Juan Grabois' :    ['JUAN GRABOIS', 'Juan Grabois', 'Grabois', 'Gravois', ],
    'Julio Barbaro' :    ['JULIO DONATO BARBARO', 'Julio Barbaro', 'Barbaro', ],
    'Eliodoro Martinez' :    ['ELIODORO MARTINEZ', 'Eliodoro Martinez', ],
    'Jorge Oliver' :    ['JORGE EDUARDO OLIVER', 'Jorge Oliver', ],
    'Carolina Bartolini' :    ['CARINA PAOLA BARTOLINI', 'Carolina Bartolini', 'Barotilin', ],
    'Paula Arias' :    ['PAULA LORENA ARIAS', 'Paula Arias'],
}

# lowercase and strip any extraspaces from all the candidates values
for candidate in candidates.keys():
    candidates[candidate] = [unidecode(candidate.lower().strip()) for candidate in candidates[candidate]]

# filter text based on the candidates present in the text. Add a new column 'candidate' to the df
def filter_text(text):
    text = unidecode(text)
    for candidate in candidates.keys():
        for candidate_name in candidates[candidate]:
            # deaccent spanish text
            if candidate_name in text:
                return True

    return False



# filter the text column
df = df[df['text'].progress_apply(filter_text)]
# Out:
#   0%|          | 52/345168 [00:00<11:09, 515.51it/s]
# 100%|██████████| 345168/345168 [08:49<00:00, 651.71it/s]

# %%
# add a new candidate column, add the name of candidates mentioned in the text
def add_candidate(text):
    candidates_list = set()
    for candidate in candidates.keys():
        for candidate_name in candidates[candidate]:
            if candidate_name in text:
                candidates_list.add(candidate)
    return candidates_list

df['candidate'] = df['text'].progress_apply(add_candidate)
# Out:
# 100%|██████████| 34484/34484 [00:44<00:00, 773.08it/s]

# %%
# for each candidate in the candidate column, add a new row with the same values except the candidate column
# Convert the candidate set to a string list
df['candidate_str'] = df['candidate'].apply(lambda x: list(x))
# explode the candidate column
df_exploded = df.explode('candidate_str')
df_exploded = df_exploded.reset_index(drop=True)
# drop the candidate column
df = df_exploded.drop(['candidate'], axis=1)
# rename the candidate_str column to candidate
df = df.rename(columns={'candidate_str': 'candidate'})
# make the candidate column to be the first column
df = df[['candidate', 'source', 'date', 'text']]

# %%
# rename 'Myriam Teresa Bregman' to 'Myriam Bregman' in the twitter_df candidate column
twitter_df['candidate'] = twitter_df['candidate'].progress_apply(lambda x: 'Myriam Bregman' if x=='Myriam Teresa Bregman' else x)

# append the twitter_df to the df
df = pd.concat([df, twitter_df], ignore_index=True)
df = df.reset_index(drop=True)
# Out:
# 100%|██████████| 4721/4721 [00:00<00:00, 497770.47it/s]

# %%
df
# Out:
#                 candidate   source       date  \
# 0       Patricia Bullrich   clarin 2023-09-03
# 1       Patricia Bullrich   clarin 2020-10-28
# 2                     NaN   clarin 2023-10-17
# 3      Sergio Tomas Massa   clarin 2023-09-22
# 4       Patricia Bullrich   clarin 2017-11-06
# ...                   ...      ...        ...
# 57002   Patricia Bullrich  twitter 2023-03-16
# 57003   Patricia Bullrich  twitter 2023-04-08
# 57004   Patricia Bullrich  twitter 2023-10-09
# 57005   Patricia Bullrich  twitter 2023-06-10
# 57006   Patricia Bullrich  twitter 2022-06-14
#
#                                                     text
# 0      \nEl peronismo cree ser la fuerza que más tien...
# 1      \nEn momentos en que se desarrolla la audienci...
# 2      \nA menos de una semana de las elecciones pres...
# 3      \nMientras Milei pretende disimular que no est...
# 4      \nEn una resolución con trascendencia instituc...
# ...                                                  ...
# 57002                      muy bueno el spot de bullrich
# 57003                     11 días patricia bullrich 2023
# 57004  mauricio macri diciendo que vidal se había com...
# 57005                 con bullrich se repite la historia
# 57006           milei en los ' 70 / bullrich en los ' 70
#
# [57007 rows x 4 columns]

# %%
# how many entries does each cand website have?
df['source'].value_counts()
# Out:
# source
# youtube         36236
# twitter          4721
# rionegro         3047
# eldestapeweb     3034
# lanacion         2534
# perfil           2482
# c5n              1961
# clarin           1333
# lavoz            1076
# infobae           463
# pagina12          120
# Name: count, dtype: int64

# %%
# save it as a csv
df.to_csv('preprocessed_data.csv', index=False)
